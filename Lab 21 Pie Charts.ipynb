# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2025-09-12 04:57:33--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# 169.63.118.104ourses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)...
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  62.1MB/s    in 2.4s
#
# 2025-09-12 04:57:36 (62.1 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the relevant column
QUERY = """
SELECT DatabaseWantToWorkWith
FROM main
WHERE DatabaseWantToWorkWith IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple databases into separate rows
df = df.assign(DatabaseWantToWorkWith=df['DatabaseWantToWorkWith'].str.split(';')).explode('DatabaseWantToWorkWith')
df['DatabaseWantToWorkWith'] = df['DatabaseWantToWorkWith'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each database
top5_db = df['DatabaseWantToWorkWith'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top5_db, labels=top5_db.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top 5 Desired Databases by Respondents", fontsize=16)
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the DevType column
QUERY = """
SELECT DevType
FROM main
WHERE DevType IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple developer types into separate rows
df = df.assign(DevType=df['DevType'].str.split(';')).explode('DevType')
df['DevType'] = df['DevType'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each developer type
top5_dev = df['DevType'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top5_dev, labels=top5_dev.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top 5 Developer Types", fontsize=16)
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the OpSysProfessional use column
QUERY = """
SELECT "OpSysProfessional use"
FROM main
WHERE "OpSysProfessional use" IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple operating systems into separate rows
df = df.assign(OpSys=df['OpSysProfessional use'].str.split(';')).explode('OpSys')
df['OpSys'] = df['OpSys'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each operating system
top_os = df['OpSys'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top_os, labels=top_os.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top Operating Systems Used Professionally", fontsize=16)
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the OpSysProfessional use column
QUERY = """
SELECT "OpSysProfessional use"
FROM main
WHERE "OpSysProfessional use" IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple operating systems into separate rows
df = df.assign(OpSys=df['OpSysProfessional use'].str.split(';')).explode('OpSys')
df['OpSys'] = df['OpSys'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each operating system
top_os = df['OpSys'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top_os, labels=top_os.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top Operating Systems Used Professionally", fontsize=16)
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the NEWCollabToolsHaveWorkedWith column
QUERY = """
SELECT "NEWCollabToolsHaveWorkedWith"
FROM main
WHERE "NEWCollabToolsHaveWorkedWith" IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple tools into separate rows
df = df.assign(Tool=df['NEWCollabToolsHaveWorkedWith'].str.split(';')).explode('Tool')
df['Tool'] = df['Tool'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each tool and get top 5
top_tools = df['Tool'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top_tools, labels=top_tools.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top 5 Collaboration Tools Used Professionally", fontsize=16)
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to the SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the LanguageAdmired column
QUERY = """
SELECT "LanguageAdmired"
FROM main
WHERE "LanguageAdmired" IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple languages into separate rows
df = df.assign(Language=df['LanguageAdmired'].str.split(';')).explode('Language')
df['Language'] = df['Language'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each language and get top 5
top_languages = df['Language'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top_languages, labels=top_languages.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top 5 Most Admired Programming Languages", fontsize=16)
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Connect to the SQLite database
conn = sqlite3.connect('survey-data.sqlite')

# Step 2: Query the AIToolCurrently Using column
QUERY = """
SELECT "AIToolCurrently Using"
FROM main
WHERE "AIToolCurrently Using" IS NOT NULL
"""
df = pd.read_sql_query(QUERY, conn)

# Step 3: Close the connection
conn.close()

# Step 4: Split multiple tools into separate rows
df = df.assign(Tool=df['AIToolCurrently Using'].str.split(';')).explode('Tool')
df['Tool'] = df['Tool'].str.strip()  # Remove extra spaces

# Step 5: Count frequency of each tool and get top 5
top_tools = df['Tool'].value_counts().nlargest(5)

# Step 6: Create pie chart
plt.figure(figsize=(8,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0']  # Vibrant colors
plt.pie(top_tools, labels=top_tools.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05]*5, shadow=True)
plt.title("Top 5 AI Tools Currently Used by Developers", fontsize=16)
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
